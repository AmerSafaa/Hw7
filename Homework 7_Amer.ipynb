# %%
# GW Data Analytics Bootcamp
# Safaa Amer
# Homework 7
# Distinguishing Sentiments
# News Mood

## perform a sentiment analysis of the Twitter activity of various news oulets, and to present your findings visually.
## provide a visualized summary of the sentiments expressed in Tweets sent out by the following news organizations: 
## BBC, CBS, CNN, Fox, and New York times

# %%
# Dependencies
import tweepy
import json
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import openweathermapy.core as ow
from textblob import TextBlob
from datetime import datetime


# Incorporate Seaborn if preferred 
import seaborn as sns

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Twitter API Keys
consumer_key = "x4AZF9Fa1Kjc4CntXsb1D9N"
consumer_secret = "MEn3hUZh6QHGv7HGbcfX6uksFlOB2qdpkKD8jNQvHzhTV5UR"
access_token = "938582976459403269-6SSjSPCqA8S4sUlCZ9X8P1u40Oubt"
access_token_secret = "LazC7GEholYcqzbylYKzBjMf3tLdpWUL88Km4KLAio2"

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())
api_key = "25bc90a1196e6f153eece0bc0b0fc9eb"
settings = {"units": "metric", "appid": api_key}

# %%
# Target User
news_org = ['BBC','CBS', 'CNN', 'Fox', 'New York times']

sentiment =[]
tweet_text =[]
time_tweet =[]


for target_user in news_org:

    # Lists to hold sentiments
    compound_list = []
    positive_list = []
    negative_list = []
    neutral_list = []

    # Grab 100 tweets
    public_tweets = api.user_timeline(target_user, count=100, result_type="recent")
        
    # Loop through all tweets
    for tweet in public_tweets:

        # Utilize JSON dumps to generate a pretty-printed json
        print(json.dumps(tweet, sort_keys=True, indent=4, separators=(',', ': ')))
    
   
    # Loop through all tweets
    for tweet in public_tweets:

        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        
        # Add each value to the appropriate array
        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)

    # Store the Average Sentiments
    sentiment = sentiment + [{"News_organization": target_user,"Compound": np.mean(compound_list),
             "Positive": np.mean(positive_list),
             "Neutral": np.mean(negative_list),
             "Negative": np.mean(neutral_list)}]

    # Print the Sentiments
    print(sentiment)
    print("")
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Mon Jan 01 21:34:46 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "bbc.in/1KQO3WO",
#                 "expanded_url": "http://bbc.in/1KQO3WO",
#                 "indices": [
#                     92,
#                     115
#                 ],
#                 "url": "https://t.co/yhca0n4RDg"
#             }
#         ],
#         "user_mentions": [
#             {
#                 "id": 70725281,
#                 "id_str": "70725281",
#                 "indices": [
#                     3,
#                     12
#                 ],
#                 "name": "BBC Earth",
#                 "screen_name": "BBCEarth"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 947944211701288962,
#     "id_str": "947944211701288962",
# ...

# %%
# Loop through all tweets

time_tweet= []
time=[]
converted_length=0

for tweet in public_tweets:
    # capture the tweet along with the time and date of the creation of the tweet.
        #tweet_text= tweet['text']
        time_tweet = tweet['created_at']
        time.append(time_tweet)
        converted_length=converted_length+1
        
# Convert tweet timestamps to datetime objects that can be manipulated by Python
converted_timestamps = []
for time in time_tweet:
    # https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
    converted_time = datetime.strptime(time_tweet, "%a %b %d %H:%M:%S %z %Y")
    converted_timestamps.append(converted_time)


for x in range(converted_length - 1):
    time_diff = converted_timestamps[x] - converted_timestamps[x+1]
    print('time diff %s' % time_diff)
    print('time diff, in seconds %s' % time_diff.seconds)
    print('time diff, in minutes:', time_diff.seconds/60)
    print('time diff, hours', time_diff.seconds/3600)

    # convert time_diff to hours
    time_diff = time_diff.seconds/3600
    time_diff.append(time_diff)
    Average_hrs= np.mean(time_diff)

#print("Avg. Hours Between Tweets: %s" %Average_hrs)

# %%
target_user ='BBC'

# Lists to hold sentiments
compound_list = []
positive_list = []
negative_list = []
neutral_list = []

# Grab 100 tweets
public_tweets = api.user_timeline(target_user, count=100, result_type="recent")
        
# Loop through all tweets
for tweet in public_tweets:

        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        
        # Add each value to the appropriate array
        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)

# Store the Average Sentiments
sentiments = [{"Compound": compound_list,
             "Positive": positive_list,
             "Neutral": negative_list,
             "Negative": neutral_list}]

# Loop through all tweets

time_tweet= []
time=[]
converted_length=0

for tweet in public_tweets:
    # capture the tweet along with the time and date of the creation of the tweet.
        time_tweet = tweet['created_at']
        time.append(time_tweet)
        converted_length=converted_length+1
        
# Convert tweet timestamps to datetime objects that can be manipulated by Python
converted_timestamps = []
for time in time_tweet:
    converted_time = datetime.strptime(time_tweet, "%a %b %d %H:%M:%S %z %Y")
    converted_timestamps.append(converted_time)

for x in range (98):
    time_diff = converted_timestamps[x] - converted_timestamps[x+1]
    print('time diff %s' % time_diff)
    print('time diff, in seconds %s' % time_diff.seconds)
    print('time diff, in minutes:', time_diff.seconds/60)
    print('time diff, hours', time_diff.seconds/3600)

    # convert time_diff to hours
    time_diff = time_diff.seconds/3600
# Out:
# time diff 0:00:00
# time diff, in seconds 0
# time diff, in minutes: 0.0
# time diff, hours 0.0
# time diff 0:00:00
# time diff, in seconds 0
# time diff, in minutes: 0.0
# time diff, hours 0.0
# time diff 0:00:00
# time diff, in seconds 0
# time diff, in minutes: 0.0
# time diff, hours 0.0
# time diff 0:00:00
# time diff, in seconds 0
# time diff, in minutes: 0.0
# time diff, hours 0.0
# time diff 0:00:00
# time diff, in seconds 0
# time diff, in minutes: 0.0
# time diff, hours 0.0
# time diff 0:00:00
# time diff, in seconds 0
# time diff, in minutes: 0.0
# time diff, hours 0.0
# time diff 0:00:00
# time diff, in seconds 0
# time diff, in minutes: 0.0
# time diff, hours 0.0
# time diff 0:00:00
# time diff, in seconds 0
# time diff, in minutes: 0.0
# time diff, hours 0.0
# time diff 0:00:00
# time diff, in seconds 0
# time diff, in minutes: 0.0
# time diff, hours 0.0
# time diff 0:00:00
# time diff, in seconds 0
# time diff, in minutes: 0.0
# time diff, hours 0.0
# time diff 0:00:00
# ...

# %%
# Plot 1
#scatter plot of sentiments of the last 100 tweets sent out by BBC, ranging from -1.0 to 1.0,
#where a score of 0 expresses a neutral sentiment, -1 the most negative sentiment possible, and +1 the most positive sentiment possible.
# * Each plot point will reflect the _compound_ sentiment of a tweet.
# * Sort each plot point by its relative timestamp.

plt.scatter(time_diff, compound_list, edgecolor="black", linewidths=1, marker="o", alpha=0.8)

# Incorporate the other graph properties
plt.title("BBC's Tweets Polarity")
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweet Number")
plt.ylim((-1,1))
plt.grid(True)

# Create a legend
lgnd = plt.legend(fontsize="small", mode="Expanded", 
                  numpoints=1, scatterpoints=1, 
                  loc="best", title="Tweet Times", 
                  labelspacing=0.5)
#lgnd.legendHandles[0]._sizes = [30]
#lgnd.legendHandles[1]._sizes = [30]
#lgnd.legendHandles[2]._sizes = [30]

# Save Figure
plt.savefig("Fig1.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-047bc6b39884> in <module>()
#       5 # * Sort each plot point by its relative timestamp.
#       6
# ----> 7 plt.scatter(time_diff, compound_list, edgecolor="black", linewidths=1, marker="o", alpha=0.8)
#       8
#       9 # Incorporate the other graph properties
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3355                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3356                          linewidths=linewidths, verts=verts,
# -> 3357                          edgecolors=edgecolors, data=data, **kwargs)
#    3358     finally:
#    3359         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
# ...

# %%
# Plot 2:
    
# Bar plot visualizing the _overall_ sentiments of the last 100 tweets from BBC. 
# For this plot, aggregate the compound sentiments analyzed by VADER.

x_axis = np.arange(0, len(sentiment)-1)
tick_locations = []
for x in x_axis:
    tick_locations.append(x)

plt.title("Sentiments of the last 100 tweets from BBC")
plt.xlabel("Sentiment")
plt.ylabel("Compound Sentiment")

plt.bar(time, compound, facecolor="red", alpha=0.75, align="center")
plt.xticks(x_axis)
plt.show()

# %%
#* Pull into a DataFrame the tweet's source acount, its text, its date, and its compound, positive, neutral, and negative sentiment scores.
#* Export the data in the DataFrame into a CSV file.

# open a file for writing

Tweeter_data = open('/TweeterData.csv', 'w')

# create the csv writer object

csvwriter = csv.writer(Tweeter_data)

count = 0

for tweet in Tweeter_data:

      if count == 0:

             header = tweet.keys()

             csvwriter.writerow(header)

             count += 1

      csvwriter.writerow(tweet.values())

Tweeter_data.close()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-67-a003d9bb37a3> in <module>()
#       4 # open a file for writing
#       5
# ----> 6 Tweeter_data = open('/TweeterData.csv', 'w')
#       7
#       8 # create the csv writer object
#
# PermissionError: [Errno 13] Permission denied: '/TweeterData.csv'

# %%
#* Include a written description of three observable trends based on the data. 
# CBS has the most positive compound sentiment while CNN holds the most negative compound sentiment
# There is no specific trend for the tweets
